# %%
import pandas as pd
from sqlalchemy import create_engine, text
from time import time

# %% [markdown]
# ## Connect to postgres

# %%
connection_string = 'postgresql://root:root@localhost:5431/ny_taxi'

# Create the engine
engine = create_engine(connection_string)

conn = engine.connect()

# %% [markdown]
# ## Get data

# %%
# !wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv.gz')
df.head()
# Out:
# /var/folders/4q/1m012dp12171snbzxvvcncdr0000gn/T/ipykernel_41921/4218080035.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('yellow_tripdata_2021-01.csv.gz')
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1       1.0  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2       1.0  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3       1.0  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4       2.0  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# ...

# %%
df = pd.read_csv('../../data/yellow_tripdata_2021-01.csv')
df.head()
# Out:
# /var/folders/4q/1m012dp12171snbzxvvcncdr0000gn/T/ipykernel_81665/1298598732.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/yellow_tripdata_2021-01.csv')
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1       1.0  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2       1.0  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3       1.0  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4       2.0  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1369765 entries, 0 to 1369764
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               1271413 non-null  float64
#  1   tpep_pickup_datetime   1369765 non-null  object
#  2   tpep_dropoff_datetime  1369765 non-null  object
#  3   passenger_count        1271413 non-null  float64
#  4   trip_distance          1369765 non-null  float64
#  5   RatecodeID             1271413 non-null  float64
#  6   store_and_fwd_flag     1271413 non-null  object
#  7   PULocationID           1369765 non-null  int64
#  8   DOLocationID           1369765 non-null  int64
#  9   payment_type           1271413 non-null  float64
#  10  fare_amount            1369765 non-null  float64
#  11  extra                  1369765 non-null  float64
#  12  mta_tax                1369765 non-null  float64
# ...

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data'))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" REAL,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %% [markdown]
# ## Creating empty table in postgres

# %%
df.head(0).to_sql(con=engine, name='yellow_taxi_data', if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.head(0).to_sql(con=engine, name='yellow_taxi_data', if_exists='replace')
#
# NameError: name 'engine' is not defined

# %%
tables = conn.execute(text("SELECT table_name FROM information_schema.tables where table_schema='public'"))

tables.fetchall()
# Out:
# [('yellow_taxi_data',)]

# %% [markdown]
# ### No data currently in table - yellow_taxi_data

# %%
conn.execute(text("select * from yellow_taxi_data")).fetchall()
# Out:
# []

# %% [markdown]
# # ingest data in chunks

# %%
df_iter = pd.read_csv('../../data/yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000)

engine = create_engine('postgresql://root:root@localhost:5431/ny_taxi')

# df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')

while True:
    t_start = time()

    df = next(df_iter)

    # fix the type of these two fields. Shuold be datetime
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

    df.to_sql(name = 'yellow_taxi_data', con=engine, if_exists='append')

    t_end = time()
    
    print('inserted another chunk... it took %.3f seconds' % (t_end - t_start))
# Out:
# inserted another chunk... it took 7.934 seconds
# inserted another chunk... it took 7.804 seconds
# inserted another chunk... it took 6.716 seconds
# inserted another chunk... it took 6.543 seconds
# inserted another chunk... it took 6.630 seconds
# inserted another chunk... it took 6.735 seconds
# inserted another chunk... it took 6.981 seconds
# inserted another chunk... it took 7.036 seconds
# inserted another chunk... it took 6.771 seconds
# inserted another chunk... it took 7.447 seconds
# inserted another chunk... it took 7.435 seconds
# inserted another chunk... it took 6.741 seconds
# /var/folders/4q/1m012dp12171snbzxvvcncdr0000gn/T/ipykernel_81665/512063017.py:10: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunk... it took 6.915 seconds
# inserted another chunk... it took 4.305 seconds
# ---------------------------------------------------------------------------
# ...

# %%
engine.connect().execute(text("Select count(1) from yellow_taxi_data")).fetchall()
# Out:
# [(1373885,)]

# %%
docker run -it \
    --network=pg-network \
    taxi_ingest:v001 \
    --user=root \
    --password=root \
    --host=pg-database \
    --port=5432 \
    --db=ny_taxi \
    --table=yellow_taxi_trips \
    --url="https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz"

# %% [markdown]
# A new db was created with docker compose up and we are runnign the script again with the below command. check network has changed and host

# %%
docker run -it \
    --network=docker_sql_default \
    taxi_ingest:v001 \
    --user=root \
    --password=root \
    --host=pg-database \
    --port=5432 \
    --db=ny_taxi \
    --table=yellow_taxi_trips \
    --url="https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz"

# %% [markdown]
# # Ingesting Zones table into postgres

# %%
connection_string = 'postgresql://root:root@localhost:5431/ny_taxi'

# Create the engine
engine = create_engine(connection_string)

engine.connect()

# %%
zones  = pd.read_csv('https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv')
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                      NaN          NaN
# 264         265            NaN           Outside of NYC          NaN
#
# [265 rows x 4 columns]

# %%
print(pd.io.sql.get_schema(zones, name='zones_lookup'))
# Out:
# CREATE TABLE "zones_lookup" (
# "LocationID" INTEGER,
#   "Borough" TEXT,
#   "Zone" TEXT,
#   "service_zone" TEXT
# )

# %%
zones.head(0).to_sql(con = engine, name= 'zones_lookup', if_exists = 'replace')
# Out:
# 0

# %%
engine.connect().execute(text("Select table_name from information_schema.tables where table_schema = 'public'")).fetchall()
# Out:
# [('yellow_taxi_trips',), ('zones_lookup',)]

# %%
zones.to_sql(con=engine, name='zones_lookup', if_exists='append')
# Out:
# 265

# %%
engine.connect().execute(text("select count(*) from zones_lookup")).fetchall()
# Out:
# [(265,)]

# %%
green = pd.read_csv('https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-09.csv.gz', compression='gzip')
green
# Out:
# /var/folders/4q/1m012dp12171snbzxvvcncdr0000gn/T/ipykernel_61438/368843468.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   green = pd.read_csv('https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-09.csv.gz', compression='gzip')
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-09-01 00:10:53   2019-09-01 00:23:46
# 1            2.0  2019-09-01 00:31:22   2019-09-01 00:44:37
# 2            2.0  2019-09-01 00:50:24   2019-09-01 01:03:20
# 3            2.0  2019-09-01 00:27:06   2019-09-01 00:33:22
# 4            2.0  2019-09-01 00:43:23   2019-09-01 00:59:54
# ...          ...                  ...                   ...
# 449058       NaN  2019-09-30 23:13:00   2019-09-30 23:41:00
# 449059       NaN  2019-09-30 23:26:00   2019-09-30 23:46:00
# 449060       NaN  2019-09-30 23:15:00   2019-09-30 23:43:00
# ...
